# %%
import json
from pprint import pprint as print

# %%
path = '/Users/yiqinhuang/NLP/news-deep-researcher/data/query_generation_results_2.jsonl'

# %%
with open(path, 'r', encoding='utf-8') as f:
    datapoints = []
    for line in f:
        point = json.loads(line)
        datapoints.append(point)

# %%
print(datapoints[0])
# Out:
# {'input_data': {'article': 'Internet companies drop opposition to bill '
#                            'targeting online sex trafficking\n'
#                            '\n'
#                            'By Tom Jackman \n'
#                            'November 7, 2017 at 5:20 a.m. EST\n'
#                            '\n'
#                            'UPDATE, Nov. 8: The Commerce committee unanimously '
#                            'approved the bill Wednesday, sending it to the '
#                            'full floor of the Senate. Sen. Richard Blumenthal '
#                            '(D-Conn.) said the bill now had 43 sponsors and he '
#                            'hoped it would be voted upon soon.\n'
#                            '\n'
#                            'When Congress launched an effort in August to '
#                            'enable prosecution of online sex trafficking by '
#                            'amending the Communications Decency Act, the '
#                            'titans of the Internet such as Google and Facebook '
#                            'rose up in opposition. Having to police the vast '
#                            'amount of content on their websites would be too '
#                            'burdensome, they said; smaller sites without big '
#                            'legal teams would face overwhelming liability and '
#                            'who knew what unforeseen lawsuits would be made '
#                            'possible by changing a law known as "the bedrock '
#                            'of the Internet"?\n'
#                            '\n'
#                            'But now "Big Tech," whose opposition was '
#                            'anticipated to be a major stumbling block to '
#                            'amending the law, has mostly backed down. After '
#                            'working with Senate staff members to obtain what '
#                            'they see as important changes to the language of '
#                            'the bill, the Internet Association announced late '
#                            'Friday that it supports the Stop Enabling Sex '
#                            'Traffickers Act, also known as SESTA.\n'
#                            '\n'
#                            'Mother of slain teen makes tearful plea for '
#                            'Congress to amend Internet law \n'
#                            '\n'
#                            'Also Friday, the two Democratic senators from '
#                            'California who had not weighed in on the bill, '
#                            'Kamala D. Harris and Dianne Feinstein, both '
#                            'announced their support for it. Some had thought '
#                            'that pressure from California-based Internet '
#                            'companies might sway them, but ultimately they '
#                            'endorsed the measure, removing yet another '
#                            'potential hurdle to passage.\n'
#                            '\n'
#                            'The Senate bill, and a similar one in the House, '
#                            'were inspired by the numerous court victories won '
#                            'by Backpage.com, an online classified ads site '
#                            'that hosts massive advertising for prostitution, '
#                            'including an unknown percentage of children being '
#                            'trafficked by adult pimps. Backpage has '
#                            'successfully cited the Communications Decency Act, '
#                            'which protects websites from liability for posts '
#                            'by third parties, to evade both criminal '
#                            'prosecution and civil lawsuits. As attorney '
#                            'general of California, Harris launched a criminal '
#                            'case against Backpage for prostitution, and it was '
#                            'thrown out by a judge who cited the Communications '
#                            'Decency Act.\n'
#                            '\n'
#                            "The Senate's subcommittee on investigations "
#                            'sparked congressional action when it found that '
#                            'Backpage was editing ads to remove references to '
#                            'underage prostitutes, but allowing the ads to '
#                            'remain online. Then, in July, The Washington Post '
#                            'revealed that Backpage was actively soliciting ads '
#                            'from prostitutes on other websites, and creating '
#                            'new ads for those prostitutes so that they could '
#                            'post on Backpage with just one click.\n'
#                            '\n'
#                            "Backpage has always claimed it doesn't control "
#                            'sex-related ads. New documents show otherwise. \n'
#                            '\n'
#                            'Some members of Congress called for the Justice '
#                            'Department to investigate Backpage for seemingly '
#                            'creating illegal content, not just hosting it. And '
#                            'some opponents of the new bill cited The Post '
#                            'story as evidence that Backpage could be '
#                            'prosecuted under the existing law, with no need to '
#                            'amend the law and possibly open up unforeseen '
#                            'areas of civil and criminal liability.\n'
#                            '\n'
#                            'After the bill was introduced, tech lobbyists '
#                            'worked Capitol Hill trying to drum up opposition. '
#                            'Google issued a statement saying the proposed bill '
#                            '"would be a disaster" and "would actually hinder '
#                            'the fight against sex trafficking." The bill '
#                            'amends both the Decency Act and a federal '
#                            'sex-trafficking statute.\n'
#                            '\n'
#                            'Tech companies push back as Congress tries to '
#                            'fight online sex trafficking \n'
#                            '\n'
#                            'But members of the tech community worked with '
#                            'Senate Commerce Committee staff to tweak the '
#                            'language of the bill, which is scheduled for '
#                            'markup Wednesday. One of the keys was the '
#                            'definition of "participation in a venture" in the '
#                            'anti-sex-trafficking statute, which courts have '
#                            'found did not include Internet sites hosting '
#                            'illegal content. The proposed bill originally '
#                            'defined participation as "knowing conduct, by an '
#                            'individual or entity, by any means, that assists, '
#                            'supports or facilitates a violation" of sex '
#                            'trafficking laws.\n'
#                            '\n'
#                            'Internet companies thought the phrase "by any '
#                            'means" had the potential to be broadly interpreted '
#                            "when analyzing a website's actions. The newly "
#                            'amended bill changes the definition of '
#                            'participation to simply "knowingly assisting, '
#                            'supporting, or facilitating a violation" of sex '
#                            'trafficking laws, Senate staff members said.\n'
#                            '\n'
#                            'The changes to the bill also amend the standard by '
#                            'which state prosecutors can seek to charge or sue '
#                            'websites, requiring them to meet the federal '
#                            'standard, including the new definition above, '
#                            'rather than those established by state law, which '
#                            'can vary widely.\n'
#                            '\n'
#                            'Michael Beckerman, president of the Internet '
#                            'Association, which counts Google, Twitter and '
#                            'Microsoft among its members, said in a statement '
#                            'that "Important changes made to SESTA will grant '
#                            'victims the ability to secure the justice they '
#                            'deserve, allow internet platforms to continue '
#                            'their work combating human traf... [truncated]',
#                 'priors': [{'Biography': 'Senator Richard Blumenthal is a '
#                                          'Democratic senator from Connecticut.',
#                             'Information': 'Senator Richard Blumenthal stated '
#                                            'that the bill targeting online sex '
#                                            'trafficking, known as the Stop '
#                                            'Enabling Sex Traffickers Act '
#                                            '(SESTA), now had 43 sponsors. He '
#                                            'expressed hope that the bill would '
#                                            'be voted upon soon after it was '
#                                            'unanimously approved by the '
#                                            'Commerce committee and sent to the '
#                                            'full floor of the Senate.',
#                             'Name': 'Sen. Richard Blumenthal'},
#                            {'Biography': 'The Internet Association is a trade '
#                                          'group representing major internet '
#                                          'companies, including Google, '
#                                          'Twitter, and Microsoft.',
#                             'Information': 'The Internet Association announced '
#                                            'its support for the Stop Enabling '
#                                            'Sex Traffickers Act (SESTA) after '
#                                            'working with Senate staff members '
#                                            'to make important changes to the '
#                                            'language of the bill. The '
#                                            'association believes that the '
#                                            'changes will allow victims to '
#                                            'secure justice, enable internet '
#                                            'platforms to continue combating '
#                                            'human trafficking, and protect '
#                                            'good actors in the ecosystem. The '
#                                            'association looks forward to '
#                                            'working with the House and Senate '
#                                            'as SESTA moves through the '
#                                            'legislative process.',
#                             'Name': 'Internet Association'},
#                            {'Biography': 'Kamala D. Harris is a Democratic '
#                                          'senator from California and former '
#                                          'attorney general of California.',
#                             'Information': 'Senator Kamala D. Harris announced '
#                                            'her support for the Stop Enabling '
#                                            'Sex Traffickers Act (SESTA). As '
#                                            'attorney general of California, '
#                                            'she had launched a criminal case '
#                                            'against Backpage.com for '
#                                            'prostitution, which was dismissed '
#                                            'by a judge citing the '
#                                            'Communications Decency Act. Her '
#                                            'support, along with that of '
#                                            'Senator Dianne Feinstein, removed '
#                                            "a potential hurdle to the bill's "
#                                            'passage.',
#                             'Name': 'Kamala D. Harris'},
#                            {'Biography': 'Chris Cox is a former congressman '
#                                          'who co-wrote the Communications '
#                                          'Decency Act.',
#                             'Information': 'Chris Cox testified in the House, '
#                                            'advocating for using existing laws '
#                                            'to address the problem of online '
#                                            'sex trafficking rather than '
#                                            'amending the Communications '
#                                            'Decency Act. He was brought in by '
#                                            'NetChoice, an internet trade '
#                                            'group, to support their position '
#                                            'against the Stop Enabling Sex '
#                                            'Traffickers Act (SESTA).',
#                             'Name': 'Chris Cox'}],
#                 'starting_query': "When I first read Google's press release, I "
#                                   'was struck by their strong opposition to '
#                                   'the proposed amendment to Section 230 of '
#                                   'the Communications Decency Act, despite '
#                                   'their commitment to fighting sex '
#                                   'trafficking. This contradiction piqued my '
#                                   'curiosity, leading me to explore the '
#                                   'question: How are major tech companies like '
#                                   'Google balancing their advocacy against sex '
#                                   'trafficking with their concerns about '
#                                   'potential legal liabilities from the '
#                                   'proposed legislative changes?',
#                 'target': {'Biography': 'Dianne Feinstein is a Democratic '
#                                         'senator from California.',
#                            'Information': 'Senator Dianne Feinstein announced '
#                                           'her support for the Stop Enabling '
#                                           'Sex Traffickers Act (SESTA). Her '
#                                           'endorsement, along with that of '
#                                           'Senator Kamala D. Harris, was '
#                                           'significant as both senators are '
#                                           'from California, where many major '
#                                           'internet companies are based. Their '
#                                           'support removed a potential hurdle '
#                                           "to the bill's passage.",
#                            'Name': 'Dianne Feinstein'}},
#  'llm_response': {'full_response': '{\n'
#                                    '  "information_gaps": [\n'
#                                    '    "How did endorsements from senators '
#                                    'representing major internet hubs affect '
#                                    'the bill’s momentum and likelihood of '
#                                    'passage?",\n'
#                                    '    "Which specific revisions to the bill '
#                                    'addressed platform liability concerns '
#                                    'while preserving anti-trafficking '
#                                    'enforcement?",\n'
#                                    '    "Which previously uncommitted senators '
#                                    'shifted to support, and how did those '
#                                    'announcements change the political '
#                                    'calculus?",\n'
#                                    '    "What factors led lawmakers to view '
#                                    'the amended liability standard as '
#                                    'sufficient to protect smaller platforms?"\n'
#                                    '  ],\n'
#                                    '  "filled_gaps": [\n'
#                                    '    {\n'
#                                    '      "gap": "How did endorsements from '
#                                    'senators representing major internet hubs '
#                                    'affect the bill’s momentum and likelihood '
#                                    'of passage?",\n'
#                                    '      "how_used_in_article": "The article '
#                                    'cites an endorsement from a prominent '
#                                    'senator representing a state hosting many '
#                                    'internet firms to show regional, '
#                                    'industry-linked obstacles were easing and '
#                                    'the bill’s path was clearer."\n'
#                                    '    },\n'
#                                    '    {\n'
#                                    '      "gap": "Which previously uncommitted '
#                                    'senators shifted to support, and how did '
#                                    'those announcements change the political '
#                                    'calculus?",\n'
#                                    '      "how_used_in_article": "It uses the '
#                                    'source to document a key lawmaker’s move '
#                                    'from neutral to supportive, framing that '
#                                    'shift as removing a potential hurdle and '
#                                    'signaling waning opposition."\n'
#                                    '    }\n'
#                                    '  ],\n'
#                                    '  "queries": [\n'
#                                    '    {\n'
#                                    '      "gap": "How did endorsements from '
#                                    'senators representing major internet hubs '
#                                    'affect the bill’s momentum and likelihood '
#                                    'of passage?",\n'
#                                    '      "reasoning": "This search targets '
#                                    'coverage of lawmakers tied to technology '
#                                    'centers and their positions on the '
#                                    'legislation. Such reporting typically '
#                                    'analyzes how these endorsements influence '
#                                    'momentum and perceived chances of passage, '
#                                    'mirroring the article’s use of that '
#                                    'information.",\n'
#                                    '      "query": "senators representing '
#                                    'major internet hubs stance on online sex '
#                                    'trafficking legislation and impact on '
#                                    'senate momentum"\n'
#                                    '    },\n'
#                                    '    {\n'
#                                    '      "gap": "Which previously uncommitted '
#                                    'senators shifted to support, and how did '
#                                    'those announcements change the political '
#                                    'calculus?",\n'
#                                    '      "reasoning": "This query seeks '
#                                    'updates about position shifts by '
#                                    'previously undecided senators. Such '
#                                    'stories usually explain how new support '
#                                    'affects whip counts and removes obstacles, '
#                                    'paralleling the article’s use of the '
#                                    'development.",\n'
#                                    '      "query": "undecided senators '
#                                    'announce support for online sex '
#                                    'trafficking bill and what it means for '
#                                    'obstacles to passage"\n'
#                                    '    }\n'
#                                    '  ]\n'
#                                    '}',
#                   'parsed_response': {'filled_gaps': [{'gap': 'How did '
#                                                               'endorsements '
#                                                               'from senators '
#                                                               'representing '
#                                                               'major internet '
#                                                               'hubs affect the '
#                                                               'bill’s momentum '
#                                                               'and likelihood '
#                                                               'of passage?',
#                                                        'how_used_in_article': 'The '
#                                                                               'article '
#                                                                               'cites '
#                                                                               'an '
#                                                                               'endorsement '
#                                                                               'from '
#                                                                               'a '
#                                                                               'prominent '
#                                                                               'senator '
#                                                                               'representing '
#                                                                               'a '
#                                                                               'state '
#                                                                               'hosting '
#                                                                               'many '
#                                                                               'internet '
#                                                                               'firms '
#                                                                               'to '
#                                                                               'show '
#                                                                               'regional, '
#                                                                               'industry-linked '
#                                                                               'obstacles '
#                                                                               'were '
#                                                                               'easing '
#                                                                               'and '
#                                                                               'the '
#                                                                               'bill’s '
#                                                                               'path '
#                                                                               'was '
#                                                                               'clearer.'},
#                                                       {'gap': 'Which '
#                                                               'previously '
#                                                               'uncommitted '
#                                                               'senators '
#                                                               'shifted to '
#                                                               'support, and '
#                                                               'how did those '
#                                                               'announcements '
#                                                               'change the '
#                                                               'political '
#                                                               'calculus?',
#                                                        'how_used_in_article': 'It '
#                                                                               'uses '
#                                                                               'the '
#                                                                               'source '
#                                                                               'to '
#                                                                               'document '
#                                                                               'a '
#                                                                               'key '
#                                                                               'lawmaker’s '
#                                                                               'move '
#                                                                               'from '
#                                                                               'neutral '
#                                                                               'to '
#                                                                               'supportive, '
#                                                                               'framing '
#                                                                               'that '
#                                                                               'shift '
#                                                                               'as '
#                                                                               'removing '
#                                                                               'a '
#                                                                               'potential '
#                                                                               'hurdle '
#                                                                               'and '
#                                                                               'signaling '
#                                                                               'waning '
#                                                                               'opposition.'}],
#                                       'information_gaps': ['How did '
#                                                            'endorsements from '
#                                                            'senators '
#                                                            'representing major '
#                                                            'internet hubs '
#                                                            'affect the bill’s '
#                                                            'momentum and '
#                                                            'likelihood of '
#                                                            'passage?',
#                                                            'Which specific '
#                                                            'revisions to the '
#                                                            'bill addressed '
#                                                            'platform liability '
#                                                            'concerns while '
#                                                            'preserving '
#                                                            'anti-trafficking '
#                                                            'enforcement?',
#                                                            'Which previously '
#                                                            'uncommitted '
#                                                            'senators shifted '
#                                                            'to support, and '
#                                                            'how did those '
#                                                            'announcements '
#                                                            'change the '
#                                                            'political '
#                                                            'calculus?',
#                                                            'What factors led '
#                                                            'lawmakers to view '
#                                                            'the amended '
#                                                            'liability standard '
#                                                            'as sufficient to '
#                                                            'protect smaller '
#                                                            'platforms?'],
#                                       'queries': [{'gap': 'How did '
#                                                           'endorsements from '
#                                                           'senators '
#                                                           'representing major '
#                                                           'internet hubs '
#                                                           'affect the bill’s '
#                                                           'momentum and '
#                                                           'likelihood of '
#                                                           'passage?',
#                                                    'query': 'senators '
#                                                             'representing '
#                                                             'major internet '
#                                                             'hubs stance on '
#                                                             'online sex '
#                                                             'trafficking '
#                                                             'legislation and '
#                                                             'impact on senate '
#                                                             'momentum',
#                                                    'reasoning': 'This search '
#                                                                 'targets '
#                                                                 'coverage of '
#                                                                 'lawmakers '
#                                                                 'tied to '
#                                                                 'technology '
#                                                                 'centers and '
#                                                                 'their '
#                                                                 'positions on '
#                                                                 'the '
#                                                                 'legislation. '
#                                                                 'Such '
#                                                                 'reporting '
#                                                                 'typically '
#                                                                 'analyzes how '
#                                                                 'these '
#                                                                 'endorsements '
#                                                                 'influence '
#                                                                 'momentum and '
#                                                                 'perceived '
#                                                                 'chances of '
#                                                                 'passage, '
#                                                                 'mirroring the '
#                                                                 'article’s use '
#                                                                 'of that '
#                                                                 'information.'},
#                                                   {'gap': 'Which previously '
#                                                           'uncommitted '
#                                                           'senators shifted to '
#                                                           'support, and how '
#                                                           'did those '
#                                                           'announcements '
#                                                           'change the '
#                                                           'political calculus?',
#                                                    'query': 'undecided '
#                                                             'senators announce '
#                                                             'support for '
#                                                             'online sex '
#                                                             'trafficking bill '
#                                                             'and what it means '
#                                                             'for obstacles to '
#                                                             'passage',
#                                                    'reasoning': 'This query '
#                                                                 'seeks updates '
#                                                                 'about '
#                                                                 'position '
#                                                                 'shifts by '
#                                                                 'previously '
#                                                                 'undecided '
#                                                                 'senators. '
#                                                                 'Such stories '
#                                                                 'usually '
#                                                                 'explain how '
#                                                                 'new support '
#                                                                 'affects whip '
#                                                                 'counts and '
#                                                                 'removes '
#                                                                 'obstacles, '
#                                                                 'paralleling '
#                                                                 'the article’s '
#                                                                 'use of the '
#                                                                 'development.'}]},
#                   'queries_only': [{'gap': 'How did endorsements from senators '
#                                            'representing major internet hubs '
#                                            'affect the bill’s momentum and '
#                                            'likelihood of passage?',
#                                     'query': 'senators representing major '
#                                              'internet hubs stance on online '
#                                              'sex trafficking legislation and '
#                                              'impact on senate momentum',
#                                     'reasoning': 'This search targets coverage '
#                                                  'of lawmakers tied to '
#                                                  'technology centers and their '
#                                                  'positions on the '
#                                                  'legislation. Such reporting '
#                                                  'typically analyzes how these '
#                                                  'endorsements influence '
#                                                  'momentum and perceived '
#                                                  'chances of passage, '
#                                                  'mirroring the article’s use '
#                                                  'of that information.'},
#                                    {'gap': 'Which previously uncommitted '
#                                            'senators shifted to support, and '
#                                            'how did those announcements change '
#                                            'the political calculus?',
#                                     'query': 'undecided senators announce '
#                                              'support for online sex '
#                                              'trafficking bill and what it '
#                                              'means for obstacles to passage',
#                                     'reasoning': 'This query seeks updates '
#                                                  'about position shifts by '
#                                                  'previously undecided '
#                                                  'senators. Such stories '
#                                                  'usually explain how new '
#                                                  'support affects whip counts '
#                                                  'and removes obstacles, '
#                                                  'paralleling the article’s '
#                                                  'use of the development.'}]},
#  'metadata': {'timestamp': '2025-10-28T21:31:02.513697', 'version': '1.0'}}

# %%
print(datapoints[1].keys())
print(datapoints[1]['llm_response']['queries_only'])
# Out:
# dict_keys(['metadata', 'input_data', 'llm_response'])
# [{'gap': 'Will the premium-release film transition to general availability for '
#          'all streaming subscribers after the initial paid window?',
#   'query': 'Will premium-access titles become available to all streaming '
#            'subscribers after the initial window?',
#   'reasoning': 'This query targets official confirmations or spokesperson '
#                'comments about whether premium titles migrate to the general '
#                'catalog. It would surface articles citing company replies or '
#                'noting a lack of response, mirroring how the source '
#                'contributes uncertainty.'},
#  {'gap': 'Did the platform change the preorder page language concerning future '
#          'availability, and will the company confirm the rationale or timing?',
#   'query': 'Have preorder page details for a premium streaming release '
#            'changed, and has the company confirmed post-window availability?',
#   'reasoning': 'This seeks reporting on observable preorder page changes and '
#                'follow-up with corporate communications. It should retrieve '
#                'pieces documenting updated language and attempts to get '
#                'comment from the company, including non-responses.'}]

# %%
print(datapoints[1]['input_data']['target'])
# Out:
# {'Biography': 'Representatives from Disney+, the streaming service owned by '
#               'The Walt Disney Company.',
#  'Information': 'FOX Business reached out to Disney+ representatives to '
#                 "confirm whether all subscribers will be able to watch 'Mulan' "
#                 'after December 4, 2020. However, the representatives did not '
#                 'immediately respond to the inquiry.',
#  'Name': 'Unnamed Disney+ representatives'}
